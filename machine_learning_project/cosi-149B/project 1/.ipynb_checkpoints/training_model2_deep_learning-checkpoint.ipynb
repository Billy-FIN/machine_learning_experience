# %%
# this model was my second attampt at this project
# better than model1

import numpy as np
import pandas as pd
import torch

# pre-process the data: converting categorical data to numerical data
data_path = "./data_training.csv"
data_pd = pd.read_csv(data_path)
categorical_data = data_pd.select_dtypes(include=["object"])
categorical_data_onehot = pd.get_dummies(categorical_data).to_numpy()

# extract the label
numerical_data = data_pd.select_dtypes(exclude=['object']).to_numpy()
numerical_data = torch.from_numpy(numerical_data).to(torch.float32)
ground_truth = numerical_data[:,14].unsqueeze(1)    # unlike model1, this is not onehot
ground_truth[ground_truth == 2] = 0

# normalization
numerical_data = numerical_data[:,:14]
mean = numerical_data.mean(dim=0)
std = numerical_data.std(dim=0)
numerical_data = (numerical_data - mean) / std

# merge the training data
merged_data = np.concatenate((numerical_data, categorical_data_onehot), axis=1)
merged_data, merged_data.shape,ground_truth
# Out:
# (array([[-0.4150783 ,  0.5058701 , -0.37399086, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.33270904,  1.2766156 , -0.37399086, ...,  0.        ,
#           0.        ,  0.        ],
#         [-2.1599154 , -1.0356209 ,  0.00387168, ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [-0.04118463,  0.5058701 ,  0.6336426 , ...,  0.        ,
#           0.        ,  1.        ],
#         [ 0.33270904,  1.2766156 ,  0.25578004, ...,  0.        ,
#           0.        ,  0.        ],
#         [-0.6643408 , -0.2648754 , -0.37399086, ...,  0.        ,
#           0.        ,  1.        ]], dtype=float32),
#  (8101, 37),
#  tensor([[1.],
#          [1.],
#          [1.],
#          ...,
#          [1.],
#          [1.],
#          [1.]]))

# %%
data = torch.from_numpy(merged_data).to(torch.float32)    # to tensor
data
# Out:
# tensor([[-0.4151,  0.5059, -0.3740,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.3327,  1.2766, -0.3740,  ...,  0.0000,  0.0000,  0.0000],
#         [-2.1599, -1.0356,  0.0039,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [-0.0412,  0.5059,  0.6336,  ...,  0.0000,  0.0000,  1.0000],
#         [ 0.3327,  1.2766,  0.2558,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.6643, -0.2649, -0.3740,  ...,  0.0000,  0.0000,  1.0000]])

# %%
# cross validation prepration
n_samples = data.shape[0]
n_val = int(0.2 * n_samples)
shuffled_indices = torch.randperm(n_samples)   # randomly choose some indices
train_indices = shuffled_indices[:-n_val]   # 80% of those random indices are marked as indices for training
val_indices = shuffled_indices[-n_val:]     # 20% of those random indices are marked as indices for validating

# split the data set for training and testing
train_set_x = data[train_indices]
train_set_y = ground_truth[train_indices]
val_set_x = data[val_indices]
val_set_y = ground_truth[val_indices]

train_set_x.shape,train_set_y.shape,val_set_x.shape,val_set_y.shape
# train_set_x,train_set_y,val_set_x,val_set_y
# Out:
# (torch.Size([6481, 37]),
#  torch.Size([6481, 1]),
#  torch.Size([1620, 37]),
#  torch.Size([1620, 1]))

# %%
import torch.nn as nn
import torch.optim as optim

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=37, out_features=2048)
        self.layer_2 = nn.Linear(in_features=2048, out_features=1024) 
        self.layer_3 = nn.Linear(in_features=1024, out_features=512)
        self.layer_4 = nn.Linear(in_features=512, out_features=128)
        self.layer_5 = nn.Linear(in_features=128, out_features=1)
    
    def forward(self, x):
        out = torch.relu(self.layer_1(x))
        out = torch.relu(self.layer_2(out))
        out = torch.relu(self.layer_3(out))
        out = torch.relu(self.layer_4(out))
        out = torch.sigmoid(self.layer_5(out))
        return out

# %%
def accuracy_fn(y_true, y_pred):
    threshold = 0.8
    y_pred = (y_pred >= threshold).int()
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100 
    return acc

# %%
def training_loop(n_epochs, optimizer, model, loss_fn,x_train,x_val,y_train,y_val):
    # putting tensors into cpu or cuda
    x_train, y_train = x_train.to(device), y_train.to(device)
    x_val, y_val = x_val.to(device), y_val.to(device)

    for epoch in range(1, n_epochs + 1):
        # train and calculate the loss
        y_train_pred = model(x_train)
        loss_train = loss_fn(y_train_pred, y_train)
        y_val_pred = model(x_val)
        loss_val = loss_fn(y_val_pred, y_val)
        
         # Auto_grad
        optimizer.zero_grad()
        loss_train.backward()
        optimizer.step()
        
        if epoch == 1 or epoch % 100 == 0:
            print('Epoch {}, Training loss {}, Validation loss {}'.format(
                epoch, float(loss_train), float(loss_val)))
            print(f"Accuracy: {accuracy_fn(y_val,y_val_pred):.2f}%")

# %%
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
print(f"Training on device {device}.")
# Out:
# Training on device cuda.

# %%
model = Net().to(device)
loss_fn = nn.BCEWithLogitsLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-1)

training_loop(
    n_epochs = 10000,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    x_train = train_set_x,
    y_train = train_set_y,
    x_val = val_set_x,
    y_val = val_set_y
)
# Out:
# Epoch 1, Training loss 0.5546505451202393, Validation loss 0.5513871908187866
# Accuracy: 15.56%
# Epoch 100, Training loss 0.5052624940872192, Validation loss 0.5002936720848083
# Accuracy: 18.70%
# Epoch 200, Training loss 0.4765622019767761, Validation loss 0.4703909754753113
# Accuracy: 84.44%
# Epoch 300, Training loss 0.4733216166496277, Validation loss 0.4671400487422943
# Accuracy: 84.44%
# Epoch 400, Training loss 0.4657106101512909, Validation loss 0.459981769323349
# Accuracy: 90.06%
# Epoch 500, Training loss 0.4580843448638916, Validation loss 0.4530009925365448
# Accuracy: 89.44%
# Epoch 600, Training loss 0.4524596631526947, Validation loss 0.4479612112045288
# Accuracy: 89.07%
# Epoch 700, Training loss 0.443093478679657, Validation loss 0.4395185112953186
# Accuracy: 88.58%
# Epoch 800, Training loss 0.43269509077072144, Validation loss 0.4301386773586273
# Accuracy: 88.21%
# Epoch 900, Training loss 0.42862609028816223, Validation loss 0.4265908896923065
# Accuracy: 89.07%
# Epoch 1000, Training loss 0.42640557885169983, Validation loss 0.42470282316207886
# Accuracy: 89.14%
# Epoch 1100, Training loss 0.42469340562820435, Validation loss 0.4230461120605469
# Accuracy: 89.38%
# Epoch 1200, Training loss 0.42310091853141785, Validation loss 0.4212367832660675
# Accuracy: 90.19%
# Epoch 1300, Training loss 0.42151492834091187, Validation loss 0.41939112544059753
# Accuracy: 90.37%
# Epoch 1400, Training loss 0.41988900303840637, Validation loss 0.4176282286643982
# Accuracy: 90.80%
# Epoch 1500, Training loss 0.41826677322387695, Validation loss 0.4161031246185303
# Accuracy: 90.74%
# Epoch 1600, Training loss 0.4168662428855896, Validation loss 0.4148308336734772
# Accuracy: 90.86%
# Epoch 1700, Training loss 0.4156726002693176, Validation loss 0.4137079417705536
# Accuracy: 90.99%
# Epoch 1800, Training loss 0.4145960211753845, Validation loss 0.4126739799976349
# Accuracy: 91.48%
# Epoch 1900, Training loss 0.4136037826538086, Validation loss 0.4117094874382019
# Accuracy: 91.91%
# Epoch 2000, Training loss 0.412687748670578, Validation loss 0.4108242392539978
# Accuracy: 92.16%
# Epoch 2100, Training loss 0.41182518005371094, Validation loss 0.41001760959625244
# Accuracy: 92.28%
# Epoch 2200, Training loss 0.4109964668750763, Validation loss 0.40928414463996887
# Accuracy: 92.22%
# Epoch 2300, Training loss 0.41017282009124756, Validation loss 0.4086003303527832
# Accuracy: 92.53%
# Epoch 2400, Training loss 0.40934398770332336, Validation loss 0.4079674184322357
# Accuracy: 92.72%
# Epoch 2500, Training loss 0.40851297974586487, Validation loss 0.4074285328388214
# Accuracy: 92.78%
# Epoch 2600, Training loss 0.4076789617538452, Validation loss 0.40697941184043884
# Accuracy: 93.09%
# Epoch 2700, Training loss 0.4068647623062134, Validation loss 0.40660470724105835
# Accuracy: 93.21%
# Epoch 2800, Training loss 0.4060955345630646, Validation loss 0.40630364418029785
# Accuracy: 93.09%
# Epoch 2900, Training loss 0.4053698778152466, Validation loss 0.40605223178863525
# Accuracy: 93.15%
# Epoch 3000, Training loss 0.40468141436576843, Validation loss 0.40582793951034546
# Accuracy: 93.09%
# Epoch 3100, Training loss 0.4040071964263916, Validation loss 0.405597984790802
# Accuracy: 93.15%
# Epoch 3200, Training loss 0.40328171849250793, Validation loss 0.4053283631801605
# Accuracy: 93.27%
# Epoch 3300, Training loss 0.402526319026947, Validation loss 0.4050315320491791
# Accuracy: 93.21%
# Epoch 3400, Training loss 0.4018074572086334, Validation loss 0.40475109219551086
# Accuracy: 93.27%
# Epoch 3500, Training loss 0.40108492970466614, Validation loss 0.40439319610595703
# Accuracy: 93.27%
# Epoch 3600, Training loss 0.40029478073120117, Validation loss 0.4040886163711548
# Accuracy: 93.40%
# Epoch 3700, Training loss 0.39956316351890564, Validation loss 0.40397000312805176
# Accuracy: 93.46%
# Epoch 3800, Training loss 0.3988819718360901, Validation loss 0.4039432406425476
# Accuracy: 93.52%
# Epoch 3900, Training loss 0.3981134295463562, Validation loss 0.40396857261657715
# Accuracy: 93.58%
# Epoch 4000, Training loss 0.39732515811920166, Validation loss 0.40388643741607666
# Accuracy: 93.77%
# Epoch 4100, Training loss 0.39664679765701294, Validation loss 0.40381094813346863
# Accuracy: 93.83%
# Epoch 4200, Training loss 0.39608728885650635, Validation loss 0.4038192629814148
# Accuracy: 93.77%
# Epoch 4300, Training loss 0.3955782949924469, Validation loss 0.40388450026512146
# Accuracy: 93.52%
# Epoch 4400, Training loss 0.39512529969215393, Validation loss 0.4039420485496521
# Accuracy: 93.52%
# Epoch 4500, Training loss 0.3947238028049469, Validation loss 0.4039703905582428
# Accuracy: 93.58%
# Epoch 4600, Training loss 0.39435577392578125, Validation loss 0.40399524569511414
# Accuracy: 93.64%
# Epoch 4700, Training loss 0.3939967751502991, Validation loss 0.40403270721435547
# Accuracy: 93.64%
# Epoch 4800, Training loss 0.39366528391838074, Validation loss 0.4040967524051666
# Accuracy: 93.70%
# Epoch 4900, Training loss 0.3933502733707428, Validation loss 0.4041813910007477
# Accuracy: 93.58%
# Epoch 5000, Training loss 0.39302903413772583, Validation loss 0.4042187035083771
# Accuracy: 93.58%
# Epoch 5100, Training loss 0.39271432161331177, Validation loss 0.4042114317417145
# Accuracy: 93.64%
# Epoch 5200, Training loss 0.3924574851989746, Validation loss 0.4042450487613678
# Accuracy: 93.64%
# Epoch 5300, Training loss 0.3922492265701294, Validation loss 0.40426939725875854
# Accuracy: 93.64%
# Epoch 5400, Training loss 0.3920675218105316, Validation loss 0.4043002128601074
# Accuracy: 93.58%
# Epoch 5500, Training loss 0.39190343022346497, Validation loss 0.40435031056404114
# Accuracy: 93.64%
# Epoch 5600, Training loss 0.39174598455429077, Validation loss 0.40443387627601624
# Accuracy: 93.64%
# Epoch 5700, Training loss 0.39158686995506287, Validation loss 0.40455445647239685
# Accuracy: 93.52%
# Epoch 5800, Training loss 0.39143720269203186, Validation loss 0.40471136569976807
# Accuracy: 93.46%
# Epoch 5900, Training loss 0.39129477739334106, Validation loss 0.40482503175735474
# Accuracy: 93.46%
# Epoch 6000, Training loss 0.39115944504737854, Validation loss 0.40490391850471497
# Accuracy: 93.46%
# Epoch 6100, Training loss 0.39102113246917725, Validation loss 0.40494129061698914
# Accuracy: 93.58%
# Epoch 6200, Training loss 0.390901654958725, Validation loss 0.4049382209777832
# Accuracy: 93.64%
# Epoch 6300, Training loss 0.3907926380634308, Validation loss 0.4049486815929413
# Accuracy: 93.70%
# Epoch 6400, Training loss 0.39070063829421997, Validation loss 0.4049529731273651
# Accuracy: 93.77%
# Epoch 6500, Training loss 0.39061784744262695, Validation loss 0.404985249042511
# Accuracy: 93.70%
# Epoch 6600, Training loss 0.39053428173065186, Validation loss 0.40503668785095215
# Accuracy: 93.70%
# Epoch 6700, Training loss 0.3904603123664856, Validation loss 0.40505480766296387
# Accuracy: 93.70%
# Epoch 6800, Training loss 0.3903924822807312, Validation loss 0.40505334734916687
# Accuracy: 93.70%
# Epoch 6900, Training loss 0.39031505584716797, Validation loss 0.4050423502922058
# Accuracy: 93.77%
# Epoch 7000, Training loss 0.39024245738983154, Validation loss 0.40501928329467773
# Accuracy: 93.77%
# Epoch 7100, Training loss 0.39018499851226807, Validation loss 0.4049844443798065
# Accuracy: 93.77%
# Epoch 7200, Training loss 0.390135794878006, Validation loss 0.40494996309280396
# Accuracy: 93.77%
# Epoch 7300, Training loss 0.39008840918540955, Validation loss 0.4049161374568939
# Accuracy: 93.58%
# Epoch 7400, Training loss 0.3900405764579773, Validation loss 0.40487876534461975
# Accuracy: 93.58%
# Epoch 7500, Training loss 0.3899937570095062, Validation loss 0.40484288334846497
# Accuracy: 93.58%
# Epoch 7600, Training loss 0.38994255661964417, Validation loss 0.4048074781894684
# Accuracy: 93.64%
# Epoch 7700, Training loss 0.389878511428833, Validation loss 0.40473178029060364
# Accuracy: 93.64%
# Epoch 7800, Training loss 0.3897332549095154, Validation loss 0.4046837389469147
# Accuracy: 93.70%
# Epoch 7900, Training loss 0.3896690607070923, Validation loss 0.40463531017303467
# Accuracy: 93.70%
# Epoch 8000, Training loss 0.3896082043647766, Validation loss 0.40459275245666504
# Accuracy: 93.77%
# Epoch 8100, Training loss 0.38954758644104004, Validation loss 0.40454837679862976
# Accuracy: 93.77%
# Epoch 8200, Training loss 0.3894919455051422, Validation loss 0.40449121594429016
# Accuracy: 93.83%
# Epoch 8300, Training loss 0.3894122838973999, Validation loss 0.40447449684143066
# Accuracy: 93.77%
# Epoch 8400, Training loss 0.3893626630306244, Validation loss 0.4044434428215027
# Accuracy: 93.77%
# Epoch 8500, Training loss 0.38932156562805176, Validation loss 0.4043640196323395
# Accuracy: 93.89%
# Epoch 8600, Training loss 0.3892405331134796, Validation loss 0.40426334738731384
# Accuracy: 93.89%
# Epoch 8700, Training loss 0.38913166522979736, Validation loss 0.4041728973388672
# Accuracy: 93.77%
# Epoch 8800, Training loss 0.3890394866466522, Validation loss 0.40424537658691406
# Accuracy: 93.89%
# Epoch 8900, Training loss 0.38894960284233093, Validation loss 0.4041506350040436
# Accuracy: 93.83%
# Epoch 9000, Training loss 0.38881492614746094, Validation loss 0.4041840434074402
# Accuracy: 93.83%
# Epoch 9100, Training loss 0.3887184262275696, Validation loss 0.40417715907096863
# Accuracy: 93.89%
# Epoch 9200, Training loss 0.3886483609676361, Validation loss 0.4041224420070648
# Accuracy: 94.01%
# Epoch 9300, Training loss 0.38857460021972656, Validation loss 0.4040115475654602
# Accuracy: 93.95%
# Epoch 9400, Training loss 0.3885212540626526, Validation loss 0.40400707721710205
# Accuracy: 93.95%
# Epoch 9500, Training loss 0.388488233089447, Validation loss 0.4039790630340576
# Accuracy: 94.07%
# Epoch 9600, Training loss 0.3884625732898712, Validation loss 0.4039367139339447
# Accuracy: 94.14%
# Epoch 9700, Training loss 0.38843998312950134, Validation loss 0.40387988090515137
# Accuracy: 94.14%
# Epoch 9800, Training loss 0.38841232657432556, Validation loss 0.40378251671791077
# Accuracy: 94.20%
# Epoch 9900, Training loss 0.38838186860084534, Validation loss 0.4036993384361267
# Accuracy: 94.20%
# Epoch 10000, Training loss 0.388360857963562, Validation loss 0.40368714928627014
# Accuracy: 94.20%

# %%
torch.save(model.state_dict(), './model2.pt')
